# %% [markdown]
# # Week 8 Lab: Data Transformation
# The data for this set of exercises came from the [Bank for International Settlements](https://data.bis.org/topics/CBPOL/data?ref=bambooweekly.com&filter=FREQ%3DM%255ETIMESPAN%3D2000-01-01_2025-11-03). It contains monthly interest rates for a range of countries between 2000 and 2025. We will perform some transformation of this data to understand how interest rates have changed over the last 25 years. In todays lab exercise, try to write a few sentences describing your findings from the data after each question.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load & Clean Data
# Load the file called `bis_interest_rates.csv`, if there are errors, investigate the file, remember the `skiprows` parameter tells pandas how many lines to skip from the top of the file.

# %%
# Write your code here

# %% [markdown]
# ### Verify Data
# Check how many rows there are in the dataset by looking at the `shape` attribute of the DataFrame, then check how many of the columns have missing values.

# %%
# Write your code here

# %% [markdown]
# Use an `ffill` to fill any missing values in dataset if we assume that any missing values can be copied forward. Then check how many missing values there are remaining. <mark>We can ignore any missing values at the top of the dataset.</mark>

# %%
# Write your code here

# %% [markdown]
# ### Set Index
# We can use the `TIME_PERIOD:Period` as an index since all the values are unique, this will make future operations easier. Use the `set_index` method to set it as the index of the DataFrame.

# %%
# Write your code here

# %% [markdown]
# ## Analysis
# ### Largest & Smallest
# Which 10 countries have the largest interest rates from the last row in the dataset? Remember, `.iloc[-1]` returns a Series containing the last row

# %%
# Write your code here

# %% [markdown]
# Which 10 countries had the lowest interest rates in the latest data?

# %%
# Write your code here

# %% [markdown]
# ### Visualisation
# Create a line chart containing the interest rates for these banks: `['GB:United Kingdom', 'US:United States', 'XM:Euro area', 'JP:Japan']`. Pass the following parameter to the `plot` function to rotate the labels: `rot=45`

# %%
# Write your code here

# %% [markdown]
# Create a box plot showing the same data

# %%
# Write your code here

# %% [markdown]
# ### Apply a Mean
# What is the average interest rate across all countries from the latest data?

# %%
# Write your code here

# %% [markdown]
# Calculate the mean value for each date in the dataset and create a line chart to change over time.

# %%
# Write your code here

# %% [markdown]
# Which 10 countries have the highest divergence from their overall mean in the dataset?
# - Hint: take away the mean for all countries from the latest value in the dataset

# %%
# Write your code here

# %% [markdown]
# ### Correlation
# Which ten countries have the closest correlation to interest rate descisions made by `US:United States`?
# - Calculate the precentage change and the check the `US:United States` column for correlations

# %%
# Write your code here

# %% [markdown]
# Which ten countries are least correlated with `US:United States`?

# %%
# Write your code here
