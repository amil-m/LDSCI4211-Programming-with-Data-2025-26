# %% [markdown]
# # AE1: Set Exercises
# ## Task 1 (10 Points)
# Load the provided `moon_missions.csv` file using the csv module from the Python Standard Library in an appropriate format, preforming any type conversions if necessary. Your answer should discuss why any type conversion was or not needed for any values in this dataset and how you arrived at this decision.

# %%
# Write your code here

# %% [markdown]
# ## Task 2
# Create a new key called `year` in each row, the value should contain the year mission took place in YYYY format.
#
# Hint: read the last two digits of the `launch_date column`, add the string `19` to the start if the value is less than `0` when converted to an integer. Otherwise add `20` to start of the value.

# %%
# Write your code here

# %% [markdown]
# ## Task 3
# Use the `sorted` function to order the dataset by the `year` key that you created in task 2. List the ten latest moon missions on the dataset.

# %%
# Write your code here

# %% [markdown]
# ## Task 4
# Write a function called `show_info()` that prints out the count for all moon missions from a given year. The function should check that the argument given to the function is an integer.

# %%
# Write your code here

# %% [markdown]
# ## Task 5
# Choose an appropriate visualisation to show how many missions there have been each year and justify your choice of visualisation.

# %%
# Write your code here

# %% [markdown]
# ## Task 6
# Create a visualisation that shows the number of missions per country ranked in order and justify your choice of visualisation.

# %%
# Write your code here

# %% [markdown]
# ## Task 7
# Create a visualisation that shows the proportions of the different types of missions in the dataset and justify your choice of visualisation.

# %%
# Write your code here

# %% [markdown]
# ## Task 8
# Calculate the proportion of successful missions per country.

# %%
# Write your code here
