# %% [markdown]
# # Week 3 Lab
# ## Functions
# ### Task 1
# Create a function named `greet` that takes a name as a parameter and prints a personalized greeting.

# %%
# Write your code here

# %% [markdown]
# ### Task 2
# Create a function that takes a string and a number, then returns the string repeated that many times.

# %%
# Write your code here

# %% [markdown]
# ### Task 3
# Create a function with a docstring explaining its purpose, parameters, and return value. Then demonstrate how to access this documentation.

# %%
# Write your code here

# %% [markdown]
# ### Task 4
# Create a function that takes multiple numbers and returns both the minimum and maximum values
#
# *Hints:*
# - *Take a look at the documentation for the [min](https://docs.python.org/3/library/functions.html#min) and [max](https://docs.python.org/3/library/functions.html#max) built-in functions*
# - *You can return mutiple objects from a return statement by seperating them with commas*
#   `return x, y`

# %%
# Write your code here

# %% [markdown]
# ### Task 5
# Make a function that calculates simple interest given principal, rate, and months in time.
#
# The formula for simple interest is:
#
# $$Principle \times Rate of Interest \times Time Period (years) \over 100$$
#
# *Hint: Convert the number of months into a year first, 6 months is 0.5 years*

# %%
# Write your code here

# %% [markdown]
# ### Task 6
# Make a function that takes a full name and returns the person's initials.
#
# *Hint: Take a look at the documentation for the [split](https://docs.python.org/3/library/stdtypes.html#str.split) and [title](https://docs.python.org/3/library/stdtypes.html#str.title) methods*
#
# #### Expected Output
# ```python
# initials("Jay Gatsby")
# ```
# Should return:
# ```
# J.G.
# ```

# %%
# Write your code here

# %% [markdown]
# ### Task 7
# Make a function that counts the number of vowels in a given string.
#
# *Hint: You can use an [in expression](https://docs.python.org/3/reference/expressions.html#in) to check for membership of a given sequence:*
#
# ```python
# if "f" in "abcdef":
#     print("Found member!")
# ```

# %%
# Write code here

# %% [markdown]
# ### Task 8
# Explain why the `global` keyword is used inside the `increment_counter()` function:
#
# ```python
# counter = 0
#
# def increment_counter():
#     global counter
#     counter += 1
#     print(f"Counter is now: {counter}")
#
# def main():
#     print(f"Initial counter: {counter}")
#     increment_counter()
#     increment_counter()
#     print(f"Final counter: {counter}")
#
# main()
# ```
