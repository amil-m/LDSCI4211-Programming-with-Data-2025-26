# %% [markdown]
# # AE2 - Data Analysis
# Conduct an analysis of the coverage and performance of fixed broadband in the UK between the years 2018-2024. The rollout of fibre-broadband in the country has been hailed as a successful intervention by the market regulator OFCOM. Look at recent reports by OFCOM’s [Connected Nations 2024](https://www.ofcom.org.uk/phones-and-broadband/coverage-and-speeds/connected-nations-2024) before you start your assignment.
#
# This contains:
# - OFCOM Connected Nations Data (2018-2024)
#   a. Coverage data (separate files for each year)
#   b. Performance data (separate files for each year)
#   c. Contains Local Authority District codes in the `laua` column
# - [ONS Ward to Country Lookup Table](https://geoportal.statistics.gov.uk/datasets/ons::ward-to-local-authority-district-to-ctyua-to-rgn-to-ctry-may-2024-lookup-in-uk/about)
#   a. Maps local authority data to broader geographic regions
#   b. Contains `LAD24NM` column for matching with OFCOM data
#   c. Aggregate regions and countries using the `RGN24NM` and `CTRY24NM` columns
#
# You are required to produce analysis that encompasses data for all the years in the provided CSV files. You must make distinctions between the separate datasets provided for coverage and performance.
#
# ## Assessment Criteria
# Analyse the dataset to find any trends and comparisons. You must demonstrate four different forms of analysis using techniques covered in the course using only the datasets described, these should be described as questions you are asking about the data. See the assessment brief for more details.
