# %% [markdown]
# # Week 11 Lab
# The data for today came from the [Environment Agency](https://data.london.gov.uk/dataset/london-reservoir-levels-24ry5), it shows the reservoir levels in London since 1989 as percentage of usable or deployable capacity in the Lower Lee Group and Lower Thames Group reservoirs.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# - Load the dataset

# %%
# Write your code here

# %% [markdown]
# ## Data Cleaning
# - Convert the date column into Timestamps using the `to_datetime()` method
# - Set date column as the index for the DataFrame
# - Sort the index using the `sort_index()` method
#
# The data set contains a mixture of date formats, a warning message will inform you that pandas had to parse the date individually.

# %%
# Write your code here

# %% [markdown]
# - Convert the `lower_lee_group` and `lower_thames_group` columns to numbers using the `pd.to_numeric()` method, set the `errors="coerce"` argument so that it forces non-numbers to null values
# - Interpolate any missing values

# %%
# Write your code here

# %% [markdown]
# ## Resampling
# - Group all data points within each calendar year (`YE`) using resample
# - Caluculate its mean and plot as a line chart
#
# This achives the following:
# - Calculates one mean value per year (at year-end)
# - Creates a new time series with one data point per year
# - Take a look at the [Date Offsets](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) for more resampling options like `QE` for end of quarter

# %%
# Write your code here

# %% [markdown]
# ## Rolling Window
# - Calulate a rolling mean of `365` days and plot as a line chart
#
# This achieves the following:
# - Slides a 365-day window across the data
# - Calculates the mean of the last 365 days for each point
# - Preserves the original time frequency

# %%
# Write your code here

# %% [markdown]
# ## GroupBy
# Calculate the yearly average for each year of data, create a table instead of a plot.

# %%
# Write your code here

# %% [markdown]
# - Create a line chart that shows the average per month across all years.

# %%
# Write your code here

# %% [markdown]
# ## Differences
# Create a plot that shows the difference between the levels in the `lower_lee_group` and  `lower_thames_group`.

# %%
# Write your code here

# %% [markdown]
# ## Filtering
# - Filter the data since the year `2020` and call it `since_2020`
# - Resample the data to the end of the month and calculating the mean
# - Create a line chart

# %%
# Write your code here

# %% [markdown]
# - Recreate the line chart from earlier where you showed the average levels for each month with the filtered data since 2020

# %%
# Write your code here
